# %% [markdown]
# ### 這是python基礎課程
# ● python基本資料型別

# %%
print("Hello! Python!")
print("以下是python的基本資料類型(int,float,str.bool)")
15 #整數,(int)
15.0 #浮點數,(float)
"15.0" #字串,(str)
'15.0' #字串,(str)
True #布林值,(bool)
False #布林值,(bool)
# Out:
# Hello! Python!
# 以下是python的基本資料類型(int,float,str.bool)
# False

# %%
print("SELECT \"stationCode\",\"stationName\",\"stationAddrTw\"\nFROM \"台鐵車站資訊\"\nWHERE \"stationAddrTw\" LIKE \'%基隆市%\';")
# Out:
# SELECT "stationCode","stationName","stationAddrTw"
# FROM "台鐵車站資訊"
# WHERE "stationAddrTw" LIKE '%基隆市%';

# %%
"單行字串"
'單行字串'
# Out:
# '單行字串'

# %%
#多行字串

print("""select "stationCode","stationName","stationAddrTw"
FROM "台鐵車站資訊"
where "stationAddrTw" like '%基隆市%';""")
# Out:
# select "stationCode","stationName","stationAddrTw"
# FROM "台北車站資訊"
# where "stationAddrTw" like '%基隆市%';

# %%
print("""CREATE TABLE 台鐵車站資訊 (
	"stationCode" int4 NOT NULL,
	"stationName" varchar(50) NULL,
	"name" varchar(50) NULL,
	"stationAddrTw" varchar(50) NULL,
	"stationTel" varchar(50) NULL,
	gps varchar(50) NULL,
	"haveBike" varchar(50) NULL,
	CONSTRAINT 台鐵車站資訊_pkey PRIMARY KEY ("stationCode")
);""")
# Out:
# CREATE TABLE 台鐵車站資訊 (
# 	"stationCode" int4 NOT NULL,
# 	"stationName" varchar(50) NULL,
# 	"name" varchar(50) NULL,
# 	"stationAddrTw" varchar(50) NULL,
# 	"stationTel" varchar(50) NULL,
# 	gps varchar(50) NULL,
# 	"haveBike" varchar(50) NULL,
# 	CONSTRAINT 台鐵車站資訊_pkey PRIMARY KEY ("stationCode")
# );

# %%
print("""SELECT
  "stationCode",
  "stationName",
  "name"
FROM
  "台鐵車站資訊"
WHERE
  "stationAddrTw" LIKE '基隆市%';""")
# Out:
# SELECT
#   "stationCode",
#   "stationName",
#   "name"
# FROM
#   "台鐵車站資訊"
# WHERE
#   "stationAddrTw" LIKE '基隆市%';

# %% [markdown]
# ## SQL left join
# select "stationCode","stationName","stationAddrTw"
# FROM "台鐵車站資訊"
# left join 每日各站進出站人數 on "stationCode"="車站代碼"
# where "stationAddrTw" like '臺北市%';
#
#
#
# select * from 每日各站進出站人數
# left join "台鐵車站資訊" on "stationCode" ="車站代碼"
